# %%
import pandas as pd
import seaborn as sns
import matplotlib.pyplot as plt

# %%
df=pd.read_csv(r"C:\Users\shrut\Downloads\student_performance_ml.csv")
df.head()
# Out:
#    StudyHours  Attendance  PreviousScore  AssignmentsCompleted  SleepHours  \
# 0         2.0          65             45                     3           5
# 1         3.0          70             50                     4           6
# 2         4.0          75             55                     5           6
# 3         5.0          80             60                     6           7
# 4         6.0          85             65                     7           7
#
#    FinalResult
# 0            0
# 1            0
# 2            0
# 3            1
# 4            1

# %%
count=df["FinalResult"].value_counts()
print("count of final result is :",count)
# Out:
# count of final result is : FinalResult
# 1    18
# 0    12
# Name: count, dtype: int64

# %%
result=(count/len(df["FinalResult"]))*100
print("percent is :",result)
# Out:
# percent is : FinalResult
# 1    60.0
# 0    40.0
# Name: count, dtype: float64

# %%
#differnce of both percentage is only 20% so most machine learning models acceptable
